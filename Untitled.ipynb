# %%
import pandas as pd 
import json
from datetime import datetime, timedelta 
import sys

class Flight:
    
    def __init__(self, data, origin, destination, bags = 0):
        self.origin = origin
        self.destination = destination
        self.data = pd.read_csv(data)

        # all unique possible combinations between origin and destination
        self.data_c = self.data[["origin", "destination"]].drop_duplicates()

        # all unique cities in a dataframe
        self.data_s = self.data["origin"].drop_duplicates()

        # count of bags
        self.bags = bags

    # will create a graph from dataframe
    # the output of this function is a dictionary with all unique cities in df as a key
    # every key has list of values (cities), where is possible to fly straight from the key
    def create_graph(self):
        dictt = {}
        for i in self.data_s:
            a = self.data_c[self.data_c["destination"] == i]
            values = []
            for j in a["origin"]:
                values.append(j)
            dictt[i] = values
        return dictt
    
    # Depth-First search algorithm
    # will create list of list from graph above
    # in an outer list are stored all possible combinations how to get from origin (start) to destination (self.destination) with respect to grpah and dataframe
    # each combination is stored as a list
    def _dfs_util(self, graph, start, visited, path, ab, all_path):
        visited[ab.index(start)] = True
        path.append(str(start))
        if start == self.destination:
            all_path.append(list(path))
        else:
            for nextt in graph[start]:
                if visited[ab.index(nextt)] == False:
                    self._dfs_util(graph, nextt, visited, path, ab, all_path)
        path.pop()
        visited[ab.index(start)] = False
        return all_path
    
    # will cal _dfs_util() function
    def dfs(self):
        path = []
        visited = [False] * len(self.data_s)
        ab = [a for a in self.data_s]
        all_path = []
        graph = self.create_graph()
        return self._dfs_util(graph, self.origin, visited, path, ab, all_path)
    
    # will find all connections between two cities in a dataframe
    def _find_connection(self, a, b):
        return self.data[(self.data["origin"] == a) & (self.data["destination"] == b)] 

    # will return a datetime from string
    def _return_date(self, s):
        return datetime.strptime(s, "%Y-%m-%dT%H:%M:%S")
    
    # will parse seconds to HH:MM:SS format
    def _parse_time(self, s):
        hours = int(s / 3600)
        minutes = int((s - hours * 3600) / 60)
        seconds = (s - hours * 3600 - minutes * 60)
        if hours < 10:
            hours = str(0) + str(hours)
        if minutes < 10:
            minutes = str(0) + str(minutes)
        if seconds < 10:
            seconds = str(0) + str(seconds)
        return  str(hours) + ":" + str(minutes) + ":" + str(seconds)
    
    # will return required json format from pandas dataframe
    def _return_dict_format(self, df):
        ret_dict = {"flights": []}
        for row in range(len(df)):
            dictt = {}
            for col in df.columns:
                dictt[col] = df.iloc[row][col]
            ret_dict["flights"].append(dictt)

        ret_dict["bags_allowed"] = df["bags_allowed"].min()
        ret_dict["bags_count"] = self.bags
        ret_dict["destination"] = df.loc[df.index[df.shape[0] - 1]]["destination"]
        ret_dict["origin"] = df.loc[df.index[0]]["origin"]
        ret_dict["total_price"] = df["base_price"].sum() + self.bags * df["bag_price"].sum()
        ret_dict["travel_time"] = self._parse_time((self._return_date(df.iloc[len(df) - 1]["arrival"]) 
                                                    - self._return_date(df.iloc[0]["departure"])).seconds)
        return ret_dict
    
    # will check if combination given by arr list from dfs() function is available in dataframe with respect to parameters
    # similar logic to DFS algorithm 
    def _find_flights_util(self, arr, first_index, second_index, dff, all_flights):
        if (second_index == (len(arr))) & (dff.empty == False):
            if dff["bags_allowed"].min() >= self.bags:
                all_flights.append(self._return_dict_format(dff)) 
        else:
            flights = self._find_connection(arr[first_index], arr[second_index])
            for i in range(flights.shape[0]):
                if (dff.empty):
                    dff = dff.append(flights.iloc[i])
                    self._find_flights_util(arr, first_index + 1, second_index + 1, dff, all_flights)
                    dff = dff.drop(dff.index[dff.shape[0] - 1])
                elif timedelta(seconds=3600) <= (self._return_date(flights.iloc[i]["departure"]) 
                                                 - self._return_date(dff.loc[dff.index[dff.shape[0] - 1]]["arrival"])) <= timedelta(seconds=21600):
                    dff = dff.append(flights.iloc[i])
                    self._find_flights_util(arr, first_index + 1, second_index + 1, dff, all_flights)
                    dff = dff.drop(dff.index[dff.shape[0] - 1])

    # will sort list on a total_price basis               
    def _sort_function(self, e):
        return e["total_price"]

    # will call _find_flights_util() function              
    def _find_flights(self, arr, all_flights):
        dff = pd.DataFrame()
        self._find_flights_util(arr, 0, 1, dff, all_flights)
    
    # will return all flights from origin to destination available in dataframe
    # it goes through each combination from dfs() function and call _find_flights() function
    def return_all_flights(self):
        all_flights = []
        paths = self.dfs()
        for path in paths:
            self._find_flights(path, all_flights)
        all_flights.sort(key = self._sort_function)
        if len(all_flights) > 0:
            return json.dumps(all_flights, indent = 4)
        else:
            return "No flights found."

# handling inputs from terminal

# %%
f = Flight("examples/example3.csv", "WUE", "JBN")
f.create_graph()
# Out:
# {'WUE': ['JBN', 'NNB', 'EZO', 'BPZ', 'ZRW', 'VVH', 'WTN'],
#  'EZO': ['WUE', 'JBN', 'NNB', 'BPZ', 'VVH', 'WTN', 'ZRW'],
#  'NNB': ['WUE', 'EZO', 'BPZ', 'ZRW', 'JBN', 'VVH', 'WTN'],
#  'JBN': ['WUE', 'EZO', 'NNB', 'ZRW', 'VVH', 'WTN', 'BPZ'],
#  'BPZ': ['VVH', 'ZRW', 'NNB', 'EZO', 'WUE', 'JBN'],
#  'VVH': ['BPZ', 'NNB', 'EZO', 'ZRW', 'WUE', 'WTN', 'JBN'],
#  'ZRW': ['NNB', 'JBN', 'BPZ', 'VVH', 'WUE', 'EZO', 'WTN'],
#  'WTN': ['VVH', 'ZRW', 'NNB', 'JBN', 'WUE', 'EZO']}

# %%
f.dfs()
# Out:
# [['WUE', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'ZRW', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'ZRW', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'ZRW', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'WTN', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'BPZ', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'BPZ', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'NNB', 'WTN', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'BPZ', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'BPZ', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'VVH', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'NNB', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'ZRW', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'ZRW', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'ZRW', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'NNB', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'NNB', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'EZO', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'EZO', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'NNB', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'ZRW', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'ZRW', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'VVH', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'VVH', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'NNB', 'WTN', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'VVH', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'VVH', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'NNB', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'NNB', 'VVH', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'BPZ', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'NNB', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'NNB', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'NNB', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'NNB', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'NNB', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'BPZ', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'BPZ', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'BPZ', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'BPZ', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'VVH', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'VVH', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'NNB', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'NNB', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'BPZ', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'BPZ', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'BPZ', 'NNB', 'VVH', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'VVH', 'NNB', 'BPZ', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'VVH', 'NNB', 'JBN'],
#  ['WUE', 'ZRW', 'WTN', 'EZO', 'VVH', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'WTN', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'ZRW', 'WTN', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'ZRW', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'ZRW', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'WTN', 'ZRW', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'WTN', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'NNB', 'WTN', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'NNB', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'NNB', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'WTN', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'WTN', 'NNB', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'ZRW', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'ZRW', 'NNB', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'ZRW', 'WTN', 'NNB', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'EZO', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'BPZ', 'JBN'],
#  ['WUE', 'VVH', 'NNB', 'EZO', 'JBN'],
#  ['WUE', 'VVH', 'NNB', 'EZO', 'BPZ', 'ZRW', 'JBN'],
#  ['WUE', 'VVH', 'NNB', 'EZO', 'BPZ', 'ZRW', 'WTN', 'JBN'],
#  ['WUE', 'VVH', 'NNB', 'EZO', 'BPZ', 'JBN'],
#  ['WUE', 'VVH', 'NNB', 'EZO', 'WTN', 'ZRW', 'JBN'],
#  ...]
